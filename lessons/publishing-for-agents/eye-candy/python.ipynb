# %% [markdown]
# # Publishing for agents — eye candy (Python)
#
# *This notebook is a placeholder. Annie will fill it in.*
#
# **What this notebook will show:** the *eye candy* version of the
# *publishing for agents* lesson, in Python.

# %%
# Placeholder — Annie will replace with the real demo.
print('Hello from a Python kernel — this notebook is a placeholder.')
