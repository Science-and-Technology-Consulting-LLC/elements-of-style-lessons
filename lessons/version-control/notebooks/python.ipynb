# %% [markdown]
# # Version control with Git — primary (Python)
#
# *This notebook is a placeholder. Will be filled in with a real demo.*
#
# **What this notebook will show:** the *primary* version of the
# *version control with git* lesson, in Python.

# %%
# Placeholder — Replace this placeholder with the real demo.
print('Hello from a Python kernel — this notebook is a placeholder.')
